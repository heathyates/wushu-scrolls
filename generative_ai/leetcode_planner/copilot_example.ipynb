# %% [markdown]
# #
#
# ## Pre-requisites
#
# 1. Created a repository called [copilot-leetcode-planner](https://github.com/heathyates/copilot-leetcode-planner)
# 2. Made sure to use pyscaffold to create a template for `copilot-leetcode-planner`. See below for further details.
#
# ## Getting-Started
#
# 1. Navigate to my repos directory. Something like `/home/hlyates/repos`
# 2. Clone the repository with `git clone https://github.com/heathyates/copilot-leetcode-planner.git`
# 2. In the repos directory use the command `python3 -m venv env` and then `source /bin/env/activate`
# 4. Install `pip install pyscaffold`
# 5. Now run the command `putup copilot-leetcode-planner --force`
#
# We are now ready to proceed with experimenting with copilot to create

# %% [markdown]
# ## Prompt
#
# Here is the context:
# An application based on python that when run randomly selects without replacement leetcode questions in a csv file and outputs an html that balances at maximum 3 problems per week to review until all the problems in the csv file have been selected
#
# Here is additional context:
# - The problems will be in a csv file
# - The study plan should be output in an html file
# - Bonus: use mermaid to talk the architecture of the program
#
# Here is the ask: - Give a fully functional python application that meets the specifications above. Focus on simplicity - Simulate a csv file with 16 actual leetcode problems to be used for the html - Assume the user will use pyscaffold to create this application - Call the application leetcodeplanner

# %% [markdown]
# ## Copilot Response
